# %%
include("rubidium87.jl")
# Out:
# Main.rubidium87

# %%
using Plots
using LinearAlgebra
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1242

# %%
Bz_vals = range(0, 3000, length=200)
# Out:
# 0.0:15.075376884422111:3000.0

# %%
template = eigvals(Matrix(rubidium87.Hhf(0)))
all_eigvals = zeros(length(template), length(Bz_vals))
for (ind, Bz) in enumerate(Bz_vals)
    all_eigvals[:,ind] = eigvals(Matrix(rubidium87.Hhf(Bz)))
end

# %%
plot(transpose(all_eigvals))
